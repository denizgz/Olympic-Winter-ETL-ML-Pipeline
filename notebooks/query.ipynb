# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/olympics.db")
df = pd.read_sql("SELECT * FROM olympics LIMIT 5", conn)
print(df)
# Out:
#    ID                      Name Sex  Age  Height  Weight         Team  NOC  \
# 0   5  Christine Jacoba Aaftink   F   21     185      82  Netherlands  NED
# 1   5  Christine Jacoba Aaftink   F   21     185      82  Netherlands  NED
# 2   5  Christine Jacoba Aaftink   F   25     185      82  Netherlands  NED
# 3   5  Christine Jacoba Aaftink   F   25     185      82  Netherlands  NED
# 4   5  Christine Jacoba Aaftink   F   27     185      82  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1988 Winter  1988  Winter      Calgary  Speed Skating
# 1  1988 Winter  1988  Winter      Calgary  Speed Skating
# 2  1992 Winter  1992  Winter  Albertville  Speed Skating
# 3  1992 Winter  1992  Winter  Albertville  Speed Skating
# 4  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0    Speed Skating Women's 500 metres  None
# 1  Speed Skating Women's 1,000 metres  None
# ...

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/olympics.db")
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
print(tables)
# Out:
#        name
# 0  olympics
# 1  athletes
# 2       noc
